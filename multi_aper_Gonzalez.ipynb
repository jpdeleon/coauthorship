# %%
import sys
sys.path.append("/home/jp/github/research/project/pixel-ninja/")

from pixelninja import plot_apertures
# Out:
# Created TAP+ (v1.2.1) - Connection:
# 	Host: gea.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443
# Created TAP+ (v1.2.1) - Connection:
# 	Host: geadata.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443

# %%
import astropy.units as u
import numpy as np
import pandas as pd

import chronos as cr

# %%
columns = 'epic campaign epoch period depth b'.split()
df=pd.read_csv("tableA3.csv", index_col=0)
df
# Out:
#             epic  campaign        epoch  period    depth     b       a  \
# 0   2.493847e+08        15  2457991.605   1.133  0.00104  0.43  0.0147
# 1   2.493847e+08        15  2457994.123   5.260  0.00270  0.40  0.0582
# 2   2.493915e+08        15  2457991.860   1.075  0.00095  0.34  0.0173
# 3   2.495575e+08        15  2457994.132   6.220  0.00129  0.43  0.0542
# 4   2.498262e+08        15  2457997.194   7.010  0.00092  0.40  0.0911
# 5   2.500014e+08        15  2457992.286   1.705  0.00056  0.00  0.1000
# 6   2.500997e+08        15  2458003.786  17.920  0.00097  0.40  0.1417
# 7   2.016639e+08        14  2457915.592  26.680  0.00090  0.35  0.1516
# 8   2.016639e+08        14  2457911.974  35.621  0.00045  0.35  0.3501
# 9   2.017967e+08        14  2457908.602   1.995  0.00606  0.49  0.0142
# 10  2.484807e+08        14  2457909.170   2.298  0.00120  0.28  0.0410
# 11  2.485582e+08        14  2457914.022   8.205  0.00077  0.68  0.0594
# ...

# %%
df.epic.astype(int)
# Out:
# 0     249384674
# 1     249384674
# 2     249391469
# 3     249557502
# 4     249826231
# 5     250001426
# 6     250099723
# 7     201663879
# 8     201663879
# 9     201796690
# 10    248480671
# 11    248558190
# 12    248616368
# 13    248639308
# 14    248775938
# 15    248782482
# 16    246909566
# 17    245944983
# 18    246074965
# 19    246163416
# 20    246313886
# 21    246331347
# 22    246331418
# 23    246331418
# 24    246472939
# Name: epic, dtype: int64

# %%
a_Rs = df['a']*u.au.to(u.Rsun)
RpRs = np.sqrt(df['depth'])
df['t14'] = cr.t14_circ(a=a_Rs, b=df['b'], k=RpRs, p=df['period'])
df['t14']
# Out:
# 0     0.109759
# 1     0.130364
# 2     0.090956
# 3     0.160387
# 4     0.108221
# 5     0.025846
# 6     0.177963
# 7     0.252416
# 8     0.144497
# 9     0.205866
# 10    0.082858
# 11    0.157894
# 12    0.302292
# 13    0.140500
# 14    0.071572
# 15    0.227615
# 16    0.112432
# 17    0.078142
# 18    0.253141
# 19    0.013277
# 20    0.135557
# 21    0.094232
# 22    0.173890
# 23    0.178277
# 24    0.086981
# Name: t14, dtype: float64

# %%
df.to_csv('tableA3.csv')

# %%
for idx,row in df.iterrows():
    epic = row['epic'].astype(str)
    if epic == "249391469.01":
        camp = row['campaign'].astype(int)
        t0 = row['epoch']
        per = row['period']
        t14 = row['t14']
        depth = row['depth']
        print(f"./pixelninja.py {epic} {camp} {t0:.4f} {per} {t14*2:.2f} {depth*2:.4f} -r 60 -s -o spanish")
# Out:
# ./pixelninja.py 249391469.01 15 2457991.8600 1.075 0.18 0.0019 -r 60 -s -o spanish
